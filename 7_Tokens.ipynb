# %% [markdown]
# <h1 style="text-align:center; color:#005bbd; font-size:30px; font-family:Sans-serif; font-style: oblique; text-shadow: 0 0 3px white, 0 0 1px Black;">
# Tokens</h1>

# %% [markdown]
# <body style="font-family: Sans-serif;">
#     <div style="color: black; font-size: 18px; font-style: oblique; text-shadow: 0 0 3px white, 0 0 1px black; padding: 20px;">
#         <ul>
#             <li>Tokens ko samajhne ke liye, pehle yeh jaan lein ke tokens programming languages ke fundamental elements hain. Yeh code ke chhote-chhote parts hote hain jo ek specific meaning rakhte hain</li><br>
#             <li>Tokens woh basic units hain jo source code ko compile ya interpret karne ke liye use hoti hain. Yeh compiler ko yeh batate hain ke kya action perform kiya jana hai.
# </li>
#     </ul>        <hr>
#     <h3>Categories of Tokens</h3>
# <ul>
# <br><li>
#     <h4>Keywords</h4>
#     <ul>
#         <li>Yeh predefined words hain jo programming language ke syntax mein specific meanings rakhte hain.</li>
#         <li>C language mein total 32 keywords hain.</li><br>
# <table style="border-collapse: collapse;width: 100%;">
# <tr>
#         <th>Sr. No</th>
#         <th>Name</th>
#         <th>Use Case</th>
#         <th>Example</th>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>int</td>
#         <td>Defines an integer variable</td>
#         <td><code>int num = 10;</code></td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>return</td>
#         <td>Returns a value from a function</td>
#         <td><code>return 0;</code></td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>if</td>
#         <td>Conditional statement</td>
#         <td><code>if (a > 5) { ... }</code></td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>else</td>
#         <td>Alternative block if "if" is false</td>
#         <td><code>else { ... }</code></td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>for</td>
#         <td>Looping construct</td>
#         <td><code>for (int i = 0; i < 10; i++) { ... }</code></td>
#     </tr>
#     <tr>
#         <td>6</td>
#         <td>while</td>
#         <td>Another looping construct</td>
#         <td><code>while (condition) { ... }</code></td>
#     </tr>
#     <tr>
#         <td>7</td>
#         <td>do</td>
#         <td>Executes loop at least once</td>
#         <td><code>do { ... } while (condition);</code></td>
#     </tr>
#     <tr>
#         <td>8</td>
#         <td>switch</td>
#         <td>Multi-way branch statement</td>
#         <td><code>switch (x) { case 1: ... }</code></td>
#     </tr>
#     <tr>
#         <td>9</td>
#         <td>break</td>
#         <td>Exits loop or switch</td>
#         <td><code>break;</code></td>
#     </tr>
#     <tr>
#         <td>10</td>
#         <td>continue</td>
#         <td>Skips current iteration in loop</td>
#         <td><code>continue;</code></td>
#     </tr>
#     <tr>
#         <td>11</td>
#         <td>char</td>
#         <td>Defines a character variable</td>
#         <td><code>char ch = 'A';</code></td>
#     </tr>
#     <tr>
#         <td>12</td>
#         <td>float</td>
#         <td>Defines a floating-point variable</td>
#         <td><code>float num = 3.14;</code></td>
#     </tr>
#     <tr>
#         <td>13</td>
#         <td>double</td>
#         <td>Defines a double precision floating-point variable</td>
#         <td><code>double pi = 3.14159;</code></td>
#     </tr>
#     <tr>
#         <td>14</td>
#         <td>struct</td>
#         <td>Defines a structure</td>
#         <td><code>struct Student { int id; char name[20]; };</code></td>
#     </tr>
#     <tr>
#         <td>15</td>
#         <td>typedef</td>
#         <td>Creates a new type name</td>
#         <td><code>typedef int Integer;</code></td>
#     </tr>
#     <tr>
#         <td>16</td>
#         <td>void</td>
#         <td>Specifies no return type for a function</td>
#         <td><code>void functionName();</code></td>
#     </tr>
#     <tr>
#         <td>17</td>
#         <td>enum</td>
#         <td>Defines an enumeration</td>
#         <td><code>enum Colors { RED, GREEN, BLUE };</code></td>
#     </tr>
#     <tr>
#         <td>18</td>
#         <td>const</td>
#         <td>Defines a constant variable</td>
#         <td><code>const int MAX = 100;</code></td>
#     </tr>
#     <tr>
#         <td>19</td>
#         <td>extern</td>
#         <td>Declares a global variable in another file</td>
#         <td><code>extern int total;</code></td>
#     </tr>
#     <tr>
#         <td>20</td>
#         <td>static</td>
#         <td>Defines a static variable or function</td>
#         <td><code>static int count = 0;</code></td>
#     </tr>
#     <tr>
#         <td>21</td>
#         <td>sizeof</td>
#         <td>Returns size of a data type</td>
#         <td><code>sizeof(int);</code></td>
#     </tr>
#     <tr>
#         <td>22</td>
#         <td>union</td>
#         <td>Defines a union (shared memory structure)</td>
#         <td><code>union Data { int i; float f; };</code></td>
#     </tr>
#     <tr>
#         <td>23</td>
#         <td>volatile</td>
#         <td>Tells compiler variable value can change anytime</td>
#         <td><code>volatile int x;</code></td>
#     </tr>
#     <tr>
#         <td>24</td>
#         <td>goto</td>
#         <td>Jumps to a labeled statement</td>
#         <td><code>goto label;</code></td>
#     </tr>
#     <tr>
#         <td>25</td>
#         <td>auto</td>
#         <td>Defines automatic local variable</td>
#         <td><code>auto int x;</code></td>
#     </tr>
#     <tr>
#         <td>26</td>
#         <td>register</td>
#         <td>Defines a register local variable</td>
#         <td><code>register int y;</code></td>
#     </tr>
#     <tr>
#         <td>27</td>
#         <td>signed</td>
#         <td>Defines a signed integer</td>
#         <td><code>signed int a;</code></td>
#     </tr>
#     <tr>
#         <td>28</td>
#         <td>unsigned</td>
#         <td>Defines an unsigned integer</td>
#         <td><code>unsigned int b;</code></td>
#     </tr>
#     <tr>
#         <td>29</td>
#         <td>short</td>
#         <td>Defines a short integer</td>
#         <td><code>short int c;</code></td>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>long</td>
#         <td>Defines a long integer</td>
#         <td><code>long int d;</code></td>
#     </tr>
#     <tr>
#         <td>31</td>
#         <td>break</td>
#         <td>Exits a loop or switch case</td>
#         <td><code>break;</code></td>
#     </tr>
#     <tr>
#         <td>32</td>
#         <td>default</td>
#         <td>Specifies default switch case</td>
#         <td><code>default: ... </code></td>
#     </tr>
# </table>
#     </ul>
#         </li><br>
# </ul><hr>

# %% [markdown]
# <body style="font-family: Sans-serif;">
#     <div style="color: black; font-size: 18px; font-style: oblique; text-shadow: 0 0 3px white, 0 0 1px black; padding: 20px;">
#         <ul>
#             <li>Identifiers</li>
#             <ul>
#                 <br><li>Yeh user-defined names hain jo variables, functions, aur dusre entities ko refer karte hain.</li>
#                 <li>Identifiers ka kaam yeh hota hai ke wo user-defined names hotay hain jo program ke different components ko identify karte hain.</li><br>
#             <li>Example: myVariable, calculateSum, dataList.</li>
#             </ul>
#         </ul>
#     </div>
# </body><hr>

# %% [markdown]
# <body style="font-family: Sans-serif;">
#     <div style="color: black; font-size: 18px; font-style: oblique; text-shadow: 0 0 3px white, 0 0 1px black; padding: 20px;">
#         <ul>
#             <li>Constants</li>
#             <ul>
#                 <br><li>Yeh fixed values hain jo program mein use hote hain aur inhe change nahi kiya ja sakta.</li>
#                 <li>Identifiers ka kaam yeh hota hai ke wo user-defined names hotay hain jo program ke different components ko identify karte hain.</li><br>
#             </ul>
#         </ul>
#     </div>
# </body><hr>

# %% [markdown]
# <body style="font-family: Sans-serif;">
#     <div style="color: black; font-size: 18px; font-style: oblique; text-shadow: 0 0 3px white, 0 0 1px black; padding: 20px;">
#         <ul>
#             <li>Operators</li>
#             <ul>
#                 <br><li>Yeh symbols hain jo operations perform karte hain.</li>
#                 <li>Example: +, -, *, /, ==, !=.</li>
#             </ul>
#         </ul>
#     </div>
# </body><hr>

# %% [markdown]
# <body style="font-family: Sans-serif;">
#     <div style="color: black; font-size: 18px; font-style: oblique; text-shadow: 0 0 3px white, 0 0 1px black; padding: 20px;">
#         <ul>
#             <li>Special Characters</li>
#             <ul>
#                 <br><li>Yeh characters hain jo kisi specific purpose ke liye use hote hain, jaise punctuation.</li>
#                 <li>Example: ;, {, }, (, ).</li>
#             </ul>
#         </ul>
#     </div>
# </body><hr>
